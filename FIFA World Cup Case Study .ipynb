# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2.3em;color:#fff;">------------------
#
# <span style="font-family: Arial; font-weight:bold;font-size:2.3em;color:#fff;">------------------
# <span style="font-family: Arial; font-weight:bold;font-size:2.3em;color:#fa9200;">FIFA World Cup

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#0ab6fa">Dataset Information:-

# %% [markdown]
# The FIFA World Cup is a global football competition contested by the various football-playing nations of the world. It is contested every four years and is the most prestigious and important trophy in the sport of football.
#
# The FIFA World Cup, often simply called the World Cup, is an international association football competition contested by the senior men's national teams of the members of the Fédération Internationale de Football Association (FIFA), the sport's global governing body. The championship has been awarded every four years since the inaugural tournament in 1930, except in 1942 and 1946 when it was not held because of the Second World War.

# %% [markdown]
# The World Cups dataset shows all information about all the World Cups in history till 2014, while the World Cup Matches dataset shows all the results from the matches contested as part of the cups.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#0ab6fa">Problem Statement:-
#
#
#
# A new football club named ‘Brussels United FC’ has just been inaugurated. As a member of this club, you have been assigned a task to carry analysis on matches, players, and world cup data. Here we need to analyze the countries which have won the world cup the most with attendance, goal, and matches per cup based on cities. Also distribution of home and away goals. Whether playing in the home country is a factor for winning or not?
#
# **Steps needs to be followed-**
#
#
# * Total goals scored by year
# * Total matches played and qualified teams by year
# * Matches with the highest number of attendance
# * Cities that hosted highest world cup matches
# * Average attendance by city

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#0ab6fa">Data Definition:-
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">1. World Cup Matches Dataset
#
# **Year**: The year in which the match was played
#
# **Datetime**: The Date on which the match was played along with a 24 hour format time
#
# **Stage**: The stage at which the match was played
#
# **Stadium**: Stadium name where the match was held
#
# **City**: The city name, where the match was played
#
# **Home Team Name**: Home team country name
#
# **Home Team Goals**: Total goals scored by the home team by the end of the match
#
# **Away Team Goals**: Total goals scored by the away team by the end of the match
#
# **Away Team Name**: Away team country name
#
# **Win conditions**: Special win condition (if any)
#
# **Attendance**: Total crowd present at the stadium
#
# **Half-time Home Goals**: Goals scored by the home team until half time
#
# **Half-time Away Goals**: Goals scored by the away team until half time
#
# **Referee**: Name of the first referee
#
# **Assistant 1**: Name of the first assistant referee (linesman)
#
# **Assistant 2**: Name of the second assistant referee (linesman)
#
# **RoundID**: Unique ID of the Round
#
# **MatchID**: Unique ID of the Match
#
# **Home Team Initials**: Home team country's three letter initials
#
# **Away Team Initials**: Away team country's three left
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">2. World Cup Players Dataset
#
#
# **RoundID**: Unique ID of the Round
#
# **MatchID**: Unique ID of the Match
#
# **Team Initials**: Player's team country's three letter initials
#
# **Coach Name**: Player's coach name
#
# **Line-up**: Indicates whether the player was in the starting line-up or not
#
# **Shirt Number**: Player's shirt number
#
# **Player Name**: Player's name
#
# **Position**: Position that the player played in
#
# **Event**: Important event involving the player (if any)
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">3. World Cup Dataset
#
# **Year**: Year in which the world cup was held
#
# **Country**: Country where the world cup was held
#
# **Winner**: Team that won the world cup
#
# **Runners-Up**: Team that came second
#
# **Third**: Team that came third
#
# **Fourth**: Team that came fourth
#
# **GoalsScored**: Total goals scored in the world cup
#
# **QualifiedTeams**: Number of teams that qualified for the world cup
#
# **MatchesPlayed**: Total matches played in the world cup
#
# **Attendance**: Total attendance in the world cup

# %% [markdown]
# ## 1. Loading libraries and datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_match = pd.read_csv('WorldCupMatches.csv')
df_players = pd.read_csv('WorldCupPlayers.csv')
df_cup = pd.read_csv('WorldCups.csv')

# %% [markdown]
# ## 2.1 Exploring World Cup Matches dataset

# %%
df_match.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# 1                    18346.0                   2.0                   0.0
# 2                    24059.0                   2.0                   0.0
# 3                     2549.0                   1.0                   0.0
# 4                    23409.0                   0.0                   0.0
#
#                   Referee               Assistant 1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)    201.0   1096.0                FRA
# 1       WARNKEN Alberto (CHI)    201.0   1090.0                USA
# 2         BALWAY Thomas (FRA)    201.0   1093.0                YUG
# 3    MATEUCCI Francisco (URU)    201.0   1098.0                ROU
# 4  RADULESCU Constantin (ROU)    201.0   1085.0                ARG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA

# %%
df_match.tail()
# Out:
#       Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 4567   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4568   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4569   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4570   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4571   NaN      NaN   NaN     NaN  NaN            NaN              NaN
#
#       Away Team Goals Away Team Name Win conditions  Attendance  \
# 4567              NaN            NaN            NaN         NaN
# 4568              NaN            NaN            NaN         NaN
# 4569              NaN            NaN            NaN         NaN
# 4570              NaN            NaN            NaN         NaN
# 4571              NaN            NaN            NaN         NaN
#
#       Half-time Home Goals  Half-time Away Goals Referee Assistant 1  \
# 4567                   NaN                   NaN     NaN         NaN
# 4568                   NaN                   NaN     NaN         NaN
# 4569                   NaN                   NaN     NaN         NaN
# 4570                   NaN                   NaN     NaN         NaN
# 4571                   NaN                   NaN     NaN         NaN
#
#      Assistant 2  RoundID  MatchID Home Team Initials Away Team Initials
# 4567         NaN      NaN      NaN                NaN                NaN
# 4568         NaN      NaN      NaN                NaN                NaN
# 4569         NaN      NaN      NaN                NaN                NaN
# 4570         NaN      NaN      NaN                NaN                NaN
# 4571         NaN      NaN      NaN                NaN                NaN

# %%
df_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    float64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    float64
#  7   Away Team Goals       852 non-null    float64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    float64
#  12  Half-time Away Goals  852 non-null    float64
#  13  Referee               852 non-null    object
#  14  Assistant 1           852 non-null    object
#  15  Assistant 2           852 non-null    object
#  16  RoundID               852 non-null    float64
#  17  MatchID               852 non-null    float64
#  18  Home Team Initials    852 non-null    object
#  19  Away Team Initials    852 non-null    object
# dtypes: float64(8), object(12)
# memory usage: 714.5+ KB

# %%
df_match.dtypes.value_counts()
# Out:
# object     12
# float64     8
# dtype: int64

# %%
df_match.shape
# Out:
# (4572, 20)

# %%
df_match.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
def missing_check(df):
    total = df.isnull().sum().sort_values(ascending=False)   # total number of null values
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)  # percentage of values that are null
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])  # putting the above two together
    return missing_data # return the dataframe
missing_check(df_match)
# Out:
#                       Total   Percent
# Attendance             3722  0.814086
# Datetime               3720  0.813648
# Home Team Initials     3720  0.813648
# MatchID                3720  0.813648
# RoundID                3720  0.813648
# Assistant 2            3720  0.813648
# Assistant 1            3720  0.813648
# Referee                3720  0.813648
# Half-time Away Goals   3720  0.813648
# Half-time Home Goals   3720  0.813648
# Year                   3720  0.813648
# Win conditions         3720  0.813648
# Away Team Name         3720  0.813648
# Away Team Goals        3720  0.813648
# Home Team Goals        3720  0.813648
# Home Team Name         3720  0.813648
# City                   3720  0.813648
# Stadium                3720  0.813648
# Stage                  3720  0.813648
# Away Team Initials     3720  0.813648

# %% [markdown]
# We can see that there is a lot of missing values (approx. 81%) in this dataset.

# %%
plt.figure(figsize=(15,5))
((df_match.isnull().sum()/df_match.isnull().count())*100).sort_values(ascending=False).plot(kind='bar')
plt.title('Percentage of Missing Values in the dataset')
ax = plt.gca()
ax.tick_params(axis='x', labelrotation = 75)
plt.ylabel('Percentage (%)')

plt.show()

# %% [markdown]
# ## 2.1.1 Drop rows with missing values

# %% [markdown]
# **NaN values in column 'Year' are not usable in this analysis so I will delete it**

# %%
df_match.dropna(subset=['Year'], inplace=True)

# %%
df_match.dropna(subset=['Attendance'], inplace=True)

# %%
df_match[['Home Team Goals','Away Team Goals','Attendance','Half-time Home Goals','Half-time Away Goals']].describe()
# Out:
#        Home Team Goals  Away Team Goals     Attendance  Half-time Home Goals  \
# count       852.000000       852.000000     850.000000            852.000000
# mean          1.811033         1.022300   45164.800000              0.708920
# std           1.610255         1.087573   23485.249247              0.937414
# min           0.000000         0.000000    2000.000000              0.000000
# 25%           1.000000         0.000000   30000.000000              0.000000
# 50%           2.000000         1.000000   41579.500000              0.000000
# 75%           3.000000         2.000000   61374.500000              1.000000
# max          10.000000         7.000000  173850.000000              6.000000
#
#        Half-time Away Goals
# count            852.000000
# mean               0.428404
# std                0.691252
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                1.000000
# max                5.000000

# %%
missing_check(df_match)
# Out:
#                       Total  Percent
# Year                      0      0.0
# Datetime                  0      0.0
# Home Team Initials        0      0.0
# MatchID                   0      0.0
# RoundID                   0      0.0
# Assistant 2               0      0.0
# Assistant 1               0      0.0
# Referee                   0      0.0
# Half-time Away Goals      0      0.0
# Half-time Home Goals      0      0.0
# Attendance                0      0.0
# Win conditions            0      0.0
# Away Team Name            0      0.0
# Away Team Goals           0      0.0
# Home Team Goals           0      0.0
# Home Team Name            0      0.0
# City                      0      0.0
# Stadium                   0      0.0
# Stage                     0      0.0
# Away Team Initials        0      0.0

# %%
df_match.corr()
# Out:
#                           Year  Home Team Goals  Away Team Goals  Attendance  \
# Year                  1.000000        -0.382443         0.075549    0.314698
# Home Team Goals      -0.382443         1.000000         0.012480   -0.117751
# Away Team Goals       0.075549         0.012480         1.000000   -0.029801
# Attendance            0.314698        -0.117751        -0.029801    1.000000
# Half-time Home Goals -0.287370         0.730249        -0.006345   -0.126756
# Half-time Away Goals  0.022869        -0.009363         0.694065   -0.037136
# RoundID               0.344996        -0.109990        -0.005364    0.069394
# MatchID               0.634769        -0.197778         0.083245    0.164686
#
#                       Half-time Home Goals  Half-time Away Goals   RoundID  \
# Year                             -0.287370              0.022869  0.344996
# Home Team Goals                   0.730249             -0.009363 -0.109990
# Away Team Goals                  -0.006345              0.694065 -0.005364
# Attendance                       -0.126756             -0.037136  0.069394
# Half-time Home Goals              1.000000              0.021124 -0.056029
# Half-time Away Goals              0.021124              1.000000  0.011431
# RoundID                          -0.056029              0.011431  1.000000
# MatchID                          -0.163372              0.062969  0.073897
#
#                        MatchID
# Year                  0.634769
# Home Team Goals      -0.197778
# Away Team Goals       0.083245
# Attendance            0.164686
# Half-time Home Goals -0.163372
# Half-time Away Goals  0.062969
# RoundID               0.073897
# MatchID               1.000000

# %%
sns.heatmap(df_match.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2.2 Exploring World Cup Players dataset

# %%
df_players.head()
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 1      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 2      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 4      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#         Player Name Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'
# 3      Juan CARRENO      NaN  G70'
# 4   Ernest LIBERATI      NaN   NaN

# %%
df_players.tail()
# Out:
#        RoundID    MatchID Team Initials               Coach Name Line-up  \
# 37779   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
# 37780   255959  300186501           GER       LOEW Joachim (GER)       N
# 37781   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
# 37782   255959  300186501           GER       LOEW Joachim (GER)       N
# 37783   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
#
#        Shirt Number Player Name Position       Event
# 37779            19     ALVAREZ      NaN         NaN
# 37780             6     KHEDIRA      NaN         NaN
# 37781            20      AGUERO      NaN  IH46' Y65'
# 37782            21     MUSTAFI      NaN         NaN
# 37783            23     BASANTA      NaN         NaN

# %%
df_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37784 entries, 0 to 37783
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RoundID        37784 non-null  int64
#  1   MatchID        37784 non-null  int64
#  2   Team Initials  37784 non-null  object
#  3   Coach Name     37784 non-null  object
#  4   Line-up        37784 non-null  object
#  5   Shirt Number   37784 non-null  int64
#  6   Player Name    37784 non-null  object
#  7   Position       4143 non-null   object
#  8   Event          9069 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 2.6+ MB

# %%
df_players.dtypes.value_counts()
# Out:
# object    6
# int64     3
# dtype: int64

# %%
df_players.columns
# Out:
# Index(['RoundID', 'MatchID', 'Team Initials', 'Coach Name', 'Line-up',
#        'Shirt Number', 'Player Name', 'Position', 'Event'],
#       dtype='object')

# %%
df_players.shape
# Out:
# (37784, 9)

# %%
missing_check(df_players)
# Out:
#                Total   Percent
# Position       33641  0.890350
# Event          28715  0.759978
# RoundID            0  0.000000
# MatchID            0  0.000000
# Team Initials      0  0.000000
# Coach Name         0  0.000000
# Line-up            0  0.000000
# Shirt Number       0  0.000000
# Player Name        0  0.000000

# %%
plt.figure(figsize=(8,5))
((df_players.isnull().sum()/df_players.isnull().count())*100).sort_values(ascending=False).plot(kind='bar')
plt.title('Percentage of Missing Values in the dataset')
ax = plt.gca()
ax.tick_params(axis='x', labelrotation = 75)
plt.ylabel('Percentage (%)')

plt.show()

# %%
df_players.corr()
# Out:
#                RoundID   MatchID  Shirt Number
# RoundID       1.000000  0.064068      0.072988
# MatchID       0.064068  1.000000      0.103669
# Shirt Number  0.072988  0.103669      1.000000

# %% [markdown]
# ## 2.3 Exploring World Cup dataset

# %%
df_cup.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0           70              13             18    590.549
# 1           70              16             17    363.000
# 2           84              15             18    375.700
# 3           88              13             22  1.045.246
# 4          140              16             26    768.607

# %%
df_cup.tail()
# Out:
#     Year       Country   Winner   Runners-Up        Third          Fourth  \
# 15  1998        France   France       Brazil      Croatia     Netherlands
# 16  2002   Korea/Japan   Brazil      Germany       Turkey  Korea Republic
# 17  2006       Germany    Italy       France      Germany        Portugal
# 18  2010  South Africa    Spain  Netherlands      Germany         Uruguay
# 19  2014        Brazil  Germany    Argentina  Netherlands          Brazil
#
#     GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 15          171              32             64  2.785.100
# 16          161              32             64  2.705.197
# 17          147              32             64  3.359.439
# 18          145              32             64  3.178.856
# 19          171              32             64  3.386.810

# %%
df_cup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            20 non-null     int64
#  1   Country         20 non-null     object
#  2   Winner          20 non-null     object
#  3   Runners-Up      20 non-null     object
#  4   Third           20 non-null     object
#  5   Fourth          20 non-null     object
#  6   GoalsScored     20 non-null     int64
#  7   QualifiedTeams  20 non-null     int64
#  8   MatchesPlayed   20 non-null     int64
#  9   Attendance      20 non-null     object
# dtypes: int64(4), object(6)
# memory usage: 1.7+ KB

# %%
missing_check(df_cup)
# Out:
#                 Total  Percent
# Year                0      0.0
# Country             0      0.0
# Winner              0      0.0
# Runners-Up          0      0.0
# Third               0      0.0
# Fourth              0      0.0
# GoalsScored         0      0.0
# QualifiedTeams      0      0.0
# MatchesPlayed       0      0.0
# Attendance          0      0.0

# %%
df_cup.columns
# Out:
# Index(['Year', 'Country', 'Winner', 'Runners-Up', 'Third', 'Fourth',
#        'GoalsScored', 'QualifiedTeams', 'MatchesPlayed', 'Attendance'],
#       dtype='object')

# %%
df_cup.dtypes.value_counts()
# Out:
# object    6
# int64     4
# dtype: int64

# %%
df_cup.shape
# Out:
# (20, 10)

# %%
df_cup[['GoalsScored','QualifiedTeams','MatchesPlayed']].describe()
# Out:
#        GoalsScored  QualifiedTeams  MatchesPlayed
# count    20.000000       20.000000      20.000000
# mean    118.950000       21.250000      41.800000
# std      32.972836        7.268352      17.218717
# min      70.000000       13.000000      17.000000
# 25%      89.000000       16.000000      30.500000
# 50%     120.500000       16.000000      38.000000
# 75%     145.250000       26.000000      55.000000
# max     171.000000       32.000000      64.000000

# %%
#We cannot use describe() method on the column 'Attendance' because of his type (object) in this dataset

# %% [markdown]
# ## 2.3.1. Remove point and change type

# %%
df_cup['Attendance'] = df_cup.Attendance.astype(str) 
df_cup['Attendance'] = [c.replace('.','') for c in df_cup.Attendance]
df_cup['Attendance'] = df_cup.Attendance.astype(int)

# %%
df_cup[['GoalsScored','QualifiedTeams','MatchesPlayed','Attendance']].describe()
# Out:
#        GoalsScored  QualifiedTeams  MatchesPlayed    Attendance
# count    20.000000       20.000000      20.000000  2.000000e+01
# mean    118.950000       21.250000      41.800000  1.872882e+06
# std      32.972836        7.268352      17.218717  1.071842e+06
# min      70.000000       13.000000      17.000000  3.630000e+05
# 25%      89.000000       16.000000      30.500000  8.748315e+05
# 50%     120.500000       16.000000      38.000000  1.734864e+06
# 75%     145.250000       26.000000      55.000000  2.725173e+06
# max     171.000000       32.000000      64.000000  3.587538e+06

# %%
df_cup.corr()
# Out:
#                     Year  GoalsScored  QualifiedTeams  MatchesPlayed  \
# Year            1.000000     0.829886        0.895565       0.972473
# GoalsScored     0.829886     1.000000        0.866201       0.876201
# QualifiedTeams  0.895565     0.866201        1.000000       0.949164
# MatchesPlayed   0.972473     0.876201        0.949164       1.000000
# Attendance      0.953158     0.774670        0.875360       0.933243
#
#                 Attendance
# Year              0.953158
# GoalsScored       0.774670
# QualifiedTeams    0.875360
# MatchesPlayed     0.933243
# Attendance        1.000000

# %%
sns.heatmap(df_cup.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we can see, the correlation between matches played and year is 0.97. What it means is as year increased matches played also increased. We can conclude that the world cup is getting bigger as the year went by. Early world cups had few teams and were small. Now the world cup is bigger and there is a lot a teams.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#0ab6fa">Reminder :
#
#
#
# A new football club named ‘Brussels United FC’ has just been inaugurated. As a member of this club, you have been assigned a task to carry analysis on matches, players, and world cup data. Here we need to analyze the countries which have won the world cup the most with attendance, goal, and matches per cup based on cities. Also distribution of home and away goals. Whether playing in the home country is a factor for winning or not?
#
# **Steps needs to be followed-**
#
#
# * Total goals scored by year
# * Total matches played and qualified teams by year
# * Matches with the highest number of attendance
# * Cities that hosted highest world cup matches
# * Average attendance by city

# %% [markdown]
# ## 3.1 Total goals scored by year

# %%
df_match["total_goals"] = df_match["Home Team Goals"] + df_match["Away Team Goals"]

plt.figure(figsize=(13,8))
sns.boxplot(y=df_match["total_goals"], x=df_match["Year"])
plt.grid(True)
plt.title("Total goals scored during game by year")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df_cup, x="Year", y="GoalsScored")
plt.grid(True)
plt.title("Total goals scored by year")
plt.show()

# %% [markdown]
# ## 3.2 Total matches played and qualified teams by year

# %%
ax = plt.gca()

df_cup.plot(kind='line', x = "Year",y = "GoalsScored", color = "green", ax=ax,grid = True,figsize = (7,7))
df_cup.plot(kind='line', x = "Year",y = "MatchesPlayed", color = 'red', ax=ax,grid = True)
df_cup.plot(kind='line', x = "Year",y = "QualifiedTeams", color = 'b', ax=ax,grid = True)
plt.legend(loc = "upper left")
plt.show()

# %% [markdown]
# ## 3.3 Matches with the highest number of attendance

# %%
df_match.sort_values(by=['Attendance'],ascending=False).head(10)
# Out:
#        Year              Datetime           Stage  \
# 74   1950.0  16 Jul 1950 - 15:00          Group 6
# 71   1950.0  13 Jul 1950 - 15:00          Group 6
# 63   1950.0  01 Jul 1950 - 15:00          Group 1
# 70   1950.0  09 Jul 1950 - 15:00          Group 6
# 379  1986.0  07 Jun 1986 - 12:00          Group B
# 411  1986.0  29 Jun 1986 - 12:00            Final
# 397  1986.0  15 Jun 1986 - 12:00      Round of 16
# 407  1986.0  22 Jun 1986 - 12:00   Quarter-finals
# 409  1986.0  25 Jun 1986 - 16:00      Semi-finals
# 367  1986.0  03 Jun 1986 - 12:00          Group B
#
#                                        Stadium             City  \
# 74   Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro
# 71   Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro
# 63   Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro
# 70   Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro
# 379                             Estadio Azteca     Mexico City
# 411                             Estadio Azteca     Mexico City
# 397                             Estadio Azteca     Mexico City
# 407                             Estadio Azteca     Mexico City
# 409                             Estadio Azteca     Mexico City
# 367                             Estadio Azteca     Mexico City
#
#     Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 74         Uruguay              2.0              1.0         Brazil
# 71          Brazil              6.0              1.0          Spain
# 63          Brazil              2.0              0.0     Yugoslavia
# 70          Brazil              7.0              1.0         Sweden
# 379         Mexico              1.0              1.0       Paraguay
# 411      Argentina              3.0              2.0     Germany FR
# 397         Mexico              2.0              0.0       Bulgaria
# 407      Argentina              2.0              1.0        England
# 409      Argentina              2.0              0.0        Belgium
# 367        Belgium              1.0              2.0         Mexico
#
#     Win conditions  ...  Half-time Home Goals  Half-time Away Goals  \
# 74                  ...                   0.0                   0.0
# 71                  ...                   3.0                   0.0
# 63                  ...                   1.0                   0.0
# 70                  ...                   3.0                   0.0
# 379                 ...                   1.0                   0.0
# 411                 ...                   1.0                   0.0
# 397                 ...                   1.0                   0.0
# 407                 ...                   0.0                   0.0
# 409                 ...                   0.0                   0.0
# 367                 ...                   1.0                   2.0
#
#                            Referee                         Assistant 1  \
# 74             READER George (ENG)                  ELLIS Arthur (ENG)
# 71            LEAFE Reginald (ENG)               MITCHELL George (SCO)
# 63        GRIFFITHS Benjamin (WAL)                 BERANEK Alois (AUT)
# 70              ELLIS Arthur (ENG)              GARCIA Prudencio (USA)
# 379          COURTNEY George (ENG)              FREDRIKSSON Erik (SWE)
# 411     ARPPI FILHO Romualdo (BRA)              FREDRIKSSON Erik (SWE)
# 397     ARPPI FILHO Romualdo (BRA)          MENDEZ MOLINA Romulo (GUA)
# 407            BENNACEUR Ali (TUN)            ULLOA MORERA Berny (CRC)
# 409  MARQUEZ RAMIREZ Antonio (MEX)          MENDEZ MOLINA Romulo (GUA)
# 367          ESPOSITO Carlos (ARG)  SILVA VALENTE Carlos Alberto (POR)
#
#                             Assistant 2 RoundID  MatchID  Home Team Initials  \
# 74                MITCHELL George (SCO)   209.0   1190.0                 URU
# 71           DA COSTA VIEIRA Jose (POR)   209.0   1186.0                 BRA
# 63           DA COSTA VIEIRA Jose (POR)   208.0   1191.0                 BRA
# 70            DE LA SALLE Charles (FRA)   209.0   1189.0                 BRA
# 379                     IGNA Ioan (ROU)   308.0    680.0                 MEX
# 411            ULLOA MORERA Berny (CRC)  3467.0    393.0                 ARG
# 397                     IGNA Ioan (ROU)   309.0    463.0                 MEX
# 407                DOTCHEV Bogdan (BUL)   714.0    392.0                 ARG
# 409  SILVA VALENTE Carlos Alberto (POR)  3469.0    388.0                 ARG
# 367          MENDEZ MOLINA Romulo (GUA)   308.0    428.0                 BEL
#
#     Away Team Initials total_goals
# 74                 BRA         3.0
# 71                 ESP         7.0
# 63                 YUG         2.0
# 70                 SWE         8.0
# 379                PAR         2.0
# 411                FRG         5.0
# 397                BUL         2.0
# 407                ENG         3.0
# 409                BEL         2.0
# 367                MEX         3.0
#
# [10 rows x 21 columns]

# %%
df_match.loc[(df_match['Attendance']>140000)]
# Out:
#       Year              Datetime    Stage  \
# 63  1950.0  01 Jul 1950 - 15:00   Group 1
# 71  1950.0  13 Jul 1950 - 15:00   Group 6
# 74  1950.0  16 Jul 1950 - 15:00   Group 6
#
#                                       Stadium             City Home Team Name  \
# 63  Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro          Brazil
# 71  Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro          Brazil
# 74  Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro         Uruguay
#
#     Home Team Goals  Away Team Goals Away Team Name Win conditions  ...  \
# 63              2.0              0.0     Yugoslavia                 ...
# 71              6.0              1.0          Spain                 ...
# 74              2.0              1.0         Brazil                 ...
#
#     Half-time Home Goals  Half-time Away Goals                   Referee  \
# 63                   1.0                   0.0  GRIFFITHS Benjamin (WAL)
# 71                   3.0                   0.0      LEAFE Reginald (ENG)
# 74                   0.0                   0.0       READER George (ENG)
#
#               Assistant 1                 Assistant 2 RoundID  MatchID  \
# 63    BERANEK Alois (AUT)  DA COSTA VIEIRA Jose (POR)   208.0   1191.0
# 71  MITCHELL George (SCO)  DA COSTA VIEIRA Jose (POR)   209.0   1186.0
# 74     ELLIS Arthur (ENG)       MITCHELL George (SCO)   209.0   1190.0
#
#     Home Team Initials Away Team Initials total_goals
# 63                 BRA                YUG         2.0
# 71                 BRA                ESP         7.0
# 74                 URU                BRA         3.0
#
# [3 rows x 21 columns]

# %%
df_match.loc[(df_match['Stadium']=='Estadio Azteca')]
# Out:
#        Year               Datetime                  Stage         Stadium  \
# 200  1970.0   31 May 1970 - 12:00                 Group 1  Estadio Azteca
# 207  1970.0   03 Jun 1970 - 16:00                 Group 1  Estadio Azteca
# 211  1970.0   06 Jun 1970 - 16:00                 Group 1  Estadio Azteca
# 215  1970.0   07 Jun 1970 - 12:00                 Group 1  Estadio Azteca
# 219  1970.0   10 Jun 1970 - 16:00                 Group 1  Estadio Azteca
# 223  1970.0   11 Jun 1970 - 16:00                 Group 1  Estadio Azteca
# 227  1970.0   14 Jun 1970 - 12:00          Quarter-finals  Estadio Azteca
# 229  1970.0  17 June 1970 - 16:00             Semi-finals  Estadio Azteca
# 230  1970.0   20 Jun 1970 - 16:00   Match for third place  Estadio Azteca
# 231  1970.0   21 Jun 1970 - 12:00                   Final  Estadio Azteca
# 360  1986.0   31 May 1986 - 12:00                 Group A  Estadio Azteca
# 367  1986.0   03 Jun 1986 - 12:00                 Group B  Estadio Azteca
# 379  1986.0   07 Jun 1986 - 12:00                 Group B  Estadio Azteca
# 389  1986.0   11 Jun 1986 - 12:00                 Group B  Estadio Azteca
# 397  1986.0   15 Jun 1986 - 12:00             Round of 16  Estadio Azteca
# 402  1986.0   18 Jun 1986 - 12:00             Round of 16  Estadio Azteca
# 407  1986.0   22 Jun 1986 - 12:00          Quarter-finals  Estadio Azteca
# 409  1986.0   25 Jun 1986 - 16:00             Semi-finals  Estadio Azteca
# 411  1986.0   29 Jun 1986 - 12:00                   Final  Estadio Azteca
#
#              City Home Team Name  Home Team Goals  Away Team Goals  \
# 200  Mexico City          Mexico              0.0              0.0
# 207  Mexico City         Belgium              3.0              0.0
# 211  Mexico City    Soviet Union              4.0              1.0
# 215  Mexico City          Mexico              4.0              0.0
# 219  Mexico City    Soviet Union              2.0              0.0
# 223  Mexico City          Mexico              1.0              0.0
# 227  Mexico City         Uruguay              1.0              0.0
# 229  Mexico City           Italy              4.0              3.0
# 230  Mexico City      Germany FR              1.0              0.0
# 231  Mexico City          Brazil              4.0              1.0
# 360  Mexico City        Bulgaria              1.0              1.0
# 367  Mexico City         Belgium              1.0              2.0
# 379  Mexico City          Mexico              1.0              1.0
# 389  Mexico City            Iraq              0.0              1.0
# 397  Mexico City          Mexico              2.0              0.0
# 402  Mexico City         England              3.0              0.0
# 407  Mexico City       Argentina              2.0              1.0
# 409  Mexico City       Argentina              2.0              0.0
# 411  Mexico City       Argentina              3.0              2.0
#
#     Away Team Name                 Win conditions  ...  Half-time Home Goals  \
# 200   Soviet Union                                 ...                   0.0
# 207    El Salvador                                 ...                   1.0
# 211        Belgium                                 ...                   1.0
# 215    El Salvador                                 ...                   1.0
# 219    El Salvador                                 ...                   0.0
# 223        Belgium                                 ...                   1.0
# 227   Soviet Union  Uruguay win after extra time   ...                   0.0
# 229     Germany FR    Italy win after extra time   ...                   0.0
# 230        Uruguay                                 ...                   1.0
# 231          Italy                                 ...                   1.0
# 360          Italy                                 ...                   0.0
# 367         Mexico                                 ...                   1.0
# 379       Paraguay                                 ...                   1.0
# 389         Mexico                                 ...                   0.0
# 397       Bulgaria                                 ...                   1.0
# 402       Paraguay                                 ...                   1.0
# 407        England                                 ...                   0.0
# 409        Belgium                                 ...                   0.0
# 411     Germany FR                                 ...                   1.0
#
#      Half-time Away Goals                          Referee  \
# 200                   0.0           TSCHENSCHER Kurt (GER)
# 207                   0.0           RADULESCU Andrei (ROU)
# 211                   0.0             SCHEURER Ruedi (SUI)
# 215                   0.0         KANDIL Aly Hussein (EGY)
# 219                   0.0     HORMAZABAL DIAZ Rafael (CHI)
# 223                   0.0    COEREZZA Norberto Angel (ARG)
# 227                   0.0         VAN RAVENS Laurens (NED)
# 229                   0.0  YAMASAKI MALDONADO Arturo (MEX)
# 230                   0.0          SBARDELLA Antonio (ITA)
# 231                   1.0           GLOECKNER Rudolf (GDR)
# 360                   1.0           FREDRIKSSON Erik (SWE)
# 367                   2.0            ESPOSITO Carlos (ARG)
# 379                   0.0            COURTNEY George (ENG)
# 389                   0.0             PETROVIC Zoran (SRB)
# 397                   0.0       ARPPI FILHO Romualdo (BRA)
# 402                   0.0            AL SHARIF Jamal (SYR)
# 407                   0.0              BENNACEUR Ali (TUN)
# 409                   0.0    MARQUEZ RAMIREZ Antonio (MEX)
# 411                   0.0       ARPPI FILHO Romualdo (BRA)
#
#                             Assistant 1                         Assistant 2  \
# 200                 DUNSTAN Keith (BER)                   TAYLOR John (ENG)
# 207              GLOECKNER Rudolf (GDR)              TSCHENSCHER Kurt (GER)
# 211                LANDAUER Henry (USA)                  DAVIDSON Bob (SCO)
# 215                 DUNSTAN Keith (BER)                   TAYLOR John (ENG)
# 219       COEREZZA Norberto Angel (ARG)       DE MORAES Ayrton Vieira (BRA)
# 223                LANDAUER Henry (USA)        HORMAZABAL DIAZ Rafael (CHI)
# 227                  DAVIDSON Bob (SCO)              GLOECKNER Rudolf (GDR)
# 229        HORMAZABAL DIAZ Rafael (CHI)           VELASQUEZ Guillermo (COL)
# 230           MARSCHALL Ferdinand (AUT)         AGUILAR ELIZALDE Abel (MEX)
# 231                SCHEURER Ruedi (SUI)       COEREZZA Norberto Angel (ARG)
# 360        CODESAL MENDEZ Edgardo (MEX)                   ROTH Volker (GER)
# 367  SILVA VALENTE Carlos Alberto (POR)          MENDEZ MOLINA Romulo (GUA)
# 379              FREDRIKSSON Erik (SWE)                     IGNA Ioan (ROU)
# 389                  NEMETH Lajos (HUN)                 AGNOLIN Luigi (ITA)
# 397          MENDEZ MOLINA Romulo (GUA)                     IGNA Ioan (ROU)
# 402                 PONNET Alexis (BEL)       AL SHANAR Fallaj Khuzam (KSA)
# 407            ULLOA MORERA Berny (CRC)                DOTCHEV Bogdan (BUL)
# 409          MENDEZ MOLINA Romulo (GUA)  SILVA VALENTE Carlos Alberto (POR)
# 411              FREDRIKSSON Erik (SWE)            ULLOA MORERA Berny (CRC)
#
#     RoundID  MatchID  Home Team Initials Away Team Initials total_goals
# 200   250.0   1902.0                 MEX                URS         0.0
# 207   250.0   1747.0                 BEL                SLV         3.0
# 211   250.0   1753.0                 URS                BEL         5.0
# 215   250.0   1820.0                 MEX                SLV         4.0
# 219   250.0   1823.0                 URS                SLV         2.0
# 223   250.0   1752.0                 MEX                BEL         1.0
# 227   251.0   1925.0                 URU                URS         1.0
# 229   569.0   1838.0                 ITA                FRG         7.0
# 230  3477.0   1843.0                 FRG                URU         1.0
# 231  3476.0   1765.0                 BRA                ITA         5.0
# 360   308.0    459.0                 BUL                ITA         2.0
# 367   308.0    428.0                 BEL                MEX         3.0
# 379   308.0    680.0                 MEX                PAR         2.0
# 389   308.0    627.0                 IRQ                MEX         1.0
# 397   309.0    463.0                 MEX                BUL         2.0
# 402   309.0    536.0                 ENG                PAR         3.0
# 407   714.0    392.0                 ARG                ENG         3.0
# 409  3469.0    388.0                 ARG                BEL         2.0
# 411  3467.0    393.0                 ARG                FRG         5.0
#
# [19 rows x 21 columns]

# %% [markdown]
# ## 3.4 Cities that hosted highest world cup matches

# %%
df_match['City'].value_counts()
# Out:
# Mexico City        23
# Montevideo         18
# Rio De Janeiro     18
# Guadalajara        17
# Johannesburg       15
#                    ..
# Eskilstuna          1
# Orebro              1
# Reims               1
# Antibes             1
# Lille               1
# Name: City, Length: 151, dtype: int64

# %% [markdown]
# ## 3.5 Average attendance by city

# %%
avg = df_match.groupby('City')['Attendance'].mean().reset_index()

# %%
avg.sort_values(by='Attendance',ascending=False)
# Out:
#                 City    Attendance
# 79      Mexico City   93806.521739
# 67      Los Angeles   92600.875000
# 112  Rio De Janeiro   86417.333333
# 66           London   82369.600000
# 119   San Francisco   81737.333333
# ..               ...           ...
# 2             Arica    9829.571429
# 135         Trieste    9000.000000
# 110           Reims    9000.000000
# 108        Rancagua    8234.714286
# 1           Antibes    7000.000000
#
# [151 rows x 2 columns]
